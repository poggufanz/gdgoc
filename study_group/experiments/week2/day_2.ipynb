# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/20191002-items.csv')
df.head(10)
# Out:
#       itemId                 category  \
# 0  100002528  beli-harddisk-eksternal
# 1  100003785  beli-harddisk-eksternal
# 2  100004132  beli-harddisk-eksternal
# 3  100004505  beli-harddisk-eksternal
# 4  100005037  beli-harddisk-eksternal
# 5  100006860  beli-harddisk-eksternal
# 6  100007498  beli-harddisk-eksternal
# 7  100010722  beli-harddisk-eksternal
# 8  100010745  beli-harddisk-eksternal
# 9  100015720  beli-harddisk-eksternal
#
#                                                 name brandName  \
# 0  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 1  TOSHIBA Full HD Smart LED TV 40" - 40L5650VJ -...   Toshiba
# 2   Samsung 40 Inch Full HD Flat LED Digital TV 4...        LG
# 3          Sharp HD LED TV 24" - LC-24LE175I - Hitam     Sharp
# 4  Lenovo Ideapad 130-15AST LAPTOP MULTIMEDIA I A...    Lenovo
# 5  Sandisk Flashdisk Cruzer Glide CZ60 16GB + iRi...   SanDisk
# 6  Asus X407UB-BV187T Laptop Multimedia Murah I C...      Asus
# ...

# %%
print(f'Jumlah baris: {len(df)}')
print(f'Jumlah kolom: {len(df.columns)}')
# Out:
# Jumlah baris: 10942
# Jumlah kolom: 9

# %% [markdown]
# 3. Eksplorasi Data Awal

# %%
df.tail(10)
# Out:
#         itemId               category  \
# 10932  9017944  shop-televisi-digital
# 10933  9019387  shop-televisi-digital
# 10934  9102603  shop-televisi-digital
# 10935  9102699  shop-televisi-digital
# 10936  9467880  shop-televisi-digital
# 10937  9467887  shop-televisi-digital
# 10938  9467898  shop-televisi-digital
# 10939  9467899  shop-televisi-digital
# 10940  9548087  shop-televisi-digital
# 10941  9548767  shop-televisi-digital
#
#                                                     name brandName  \
# 10932  Asus ROG Strix GL503VM-ED287T Scar Edition GTX...      Asus
# 10933  Asus Notebook X441UA Intel® Core™ i3-7020U 4GB...      Asus
# 10934                       Ikedo LED TV 17 inch - Hitam     Ikedo
# 10935              Ikedo LED TV 20 inch LT-20L2U - Hitam     Ikedo
# 10936  Philips 24PHA4100S/70 Televisi LED - Khusus JA...   Philips
# 10937  Toshiba 32L3750VJ Digital Tv DVB-T2 LED TV 32"...   Toshiba
# 10938  Samsung 43K5002AK Televisi LED - Khusus JABODE...   Samsung
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10942 entries, 0 to 10941
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   itemId         10942 non-null  int64
#  1   category       10942 non-null  object
#  2   name           10942 non-null  object
#  3   brandName      10938 non-null  object
#  4   url            10942 non-null  object
#  5   price          10942 non-null  int64
#  6   averageRating  10942 non-null  int64
#  7   totalReviews   10942 non-null  int64
#  8   retrievedDate  10942 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 769.5+ KB

# %%
df.describe()
# Out:
#              itemId         price  averageRating  totalReviews
# count  1.094200e+04  1.094200e+04   10942.000000  10942.000000
# mean   2.936823e+08  3.020219e+06       4.171632     27.369494
# std    2.090568e+08  6.681453e+06       1.032055    260.253817
# min    6.068000e+03  1.000000e+03       1.000000      1.000000
# 25%    1.082924e+08  7.920000e+04       4.000000      1.000000
# 50%    3.540792e+08  1.095000e+06       4.000000      2.000000
# 75%    4.527141e+08  3.959000e+06       5.000000      7.000000
# max    7.242170e+08  2.750000e+08       5.000000   9631.000000

# %%
print(df.isnull().sum())
# Out:
# itemId           0
# category         0
# name             0
# brandName        4
# url              0
# price            0
# averageRating    0
# totalReviews     0
# retrievedDate    0
# dtype: int64

# %% [markdown]
# Data Cleaning

# %%
print(f'Jumlah baris sebelum dihapus missing data: {len(df)}')
df = df.dropna()
print(f'Jumlah baris setelah dihapus missing data: {len(df)}')
# Out:
# Jumlah baris sebelum dihapus missing data: 10942
# Jumlah baris setelah dihapus missing data: 10938

# %%
print(f"Jumlah data duplikat: {df.duplicated().sum()}")

# df = df.drop_duplicates()
# print(f"Jumlah data duplikat setelah dihapus: {df.duplicated().sum()}")
# Out:
# Jumlah data duplikat: 0

# %% [markdown]
# Visualisasi Data

# %% [markdown]
# `Library 'Seaborn' 'Matplotlib'`

# %%
plt.hist(df['price'], bins = 50)
plt.title('Distribution of Harga Produk')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
top_brands = df['brandName'].value_counts().head(10)
top_brands
# Out:
# brandName
# SanDisk      1258
# Asus          946
# No Brand      945
# Lenovo        910
# Toshiba       674
# HP            582
# Acer          445
# China OEM     421
# Samsung       333
# Polytron      323
# Name: count, dtype: int64

# %%
sns.barplot(x=top_brands.values, y=top_brands.index)
# Out:
# <Axes: ylabel='brandName'>

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#       itemId                 category  \
# 0  100002528  beli-harddisk-eksternal
# 1  100003785  beli-harddisk-eksternal
# 2  100004132  beli-harddisk-eksternal
# 3  100004505  beli-harddisk-eksternal
# 4  100005037  beli-harddisk-eksternal
#
#                                                 name brandName  \
# 0  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 1  TOSHIBA Full HD Smart LED TV 40" - 40L5650VJ -...   Toshiba
# 2   Samsung 40 Inch Full HD Flat LED Digital TV 4...        LG
# 3          Sharp HD LED TV 24" - LC-24LE175I - Hitam     Sharp
# 4  Lenovo Ideapad 130-15AST LAPTOP MULTIMEDIA I A...    Lenovo
#
#                                                  url    price  averageRating  \
# 0  https://www.lazada.co.id/products/toshiba-smar...  2499000              4
# 1  https://www.lazada.co.id/products/toshiba-full...  3788000              3
# 2  https://www.lazada.co.id/products/samsung-40-i...  3850000              3
# ...

# %%
df['price_category'] = pd.cut(df['price'],
                              bins= [0, 100_000, 500_000, 1_000_000, float('inf')], labels=['low', 'medium', 'high', 'very high'])
df.head()
# Out:
#       itemId                 category  \
# 0  100002528  beli-harddisk-eksternal
# 1  100003785  beli-harddisk-eksternal
# 2  100004132  beli-harddisk-eksternal
# 3  100004505  beli-harddisk-eksternal
# 4  100005037  beli-harddisk-eksternal
#
#                                                 name brandName  \
# 0  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 1  TOSHIBA Full HD Smart LED TV 40" - 40L5650VJ -...   Toshiba
# 2   Samsung 40 Inch Full HD Flat LED Digital TV 4...        LG
# 3          Sharp HD LED TV 24" - LC-24LE175I - Hitam     Sharp
# 4  Lenovo Ideapad 130-15AST LAPTOP MULTIMEDIA I A...    Lenovo
#
#                                                  url    price  averageRating  \
# 0  https://www.lazada.co.id/products/toshiba-smar...  2499000              4
# 1  https://www.lazada.co.id/products/toshiba-full...  3788000              3
# 2  https://www.lazada.co.id/products/samsung-40-i...  3850000              3
# ...
